# %%
from selenium import webdriver
from PIL import Image

# %%
driver = webdriver.Chrome('C://Users/dazzul/Desktop/새 폴더/더조은/chromedriver')
driver.get('http://www.opinet.co.kr')

# %%
driver.save_screenshot('opinet1.png')
Image.open('opinet1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=959x875 at 0x1EDFCD24FC8>

# %%
# 지역별 주유소 찾기메뉴로 이동
# driver.find_element_by_xpath('''//*[@id="gnb_0_0"]''').click() 
# 두번 클릭해줘야함!! (주유소/충전소 찾기 메뉴 클릭> 지역별 클릭)
# 1번: 주유소/충전소 찾기 메뉴 클릭
xpath = '''//*[@id="gnb"]/ul/li[1]/a'''
driver.find_element_by_xpath(xpath).click()

# %%
# 2번: 지역별 클릭
xpath = '''//*[@id="gnb_0_0"]/a'''
driver.find_element_by_xpath(xpath).click()

# %%
# 구 선택
gu_list_raw = driver.find_element_by_xpath('''//*[@id="SIGUNGU_NM0"]''')
gu_list = gu_list_raw.find_elements_by_tag_name('option')
gu_names = [option.get_attribute('value') for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
# 조회버튼 클릭
driver.find_element_by_xpath('''//*[@id="searRgSelect"]/span''').click()

# %%
# 엑셀다운로드버튼 클릭
driver.find_element_by_xpath('''//*[@id="glopopd_excel"]/span''').click()

# %%
# 진행상태바 라이브러리
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/e1/c1/bc1dba38b48f4ae3c4428aea669c5e27bd5a7642a74c8348451e0bd8ff86/tqdm-4.36.1-py2.py3-none-any.whl (52kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.36.1

# %%
# 반복문을 돌려 모든 구에 대한 주유소 엑셀파일을 다운로드한다.
import time

from tqdm import tqdm_notebook

 

for gu in tqdm_notebook(gu_names):

    element = driver.find_element_by_id('SIGUNGU_NM0')

    element.send_keys(gu)

    

    time.sleep(2)

    

    xpath ='''//*[@id="searRgSelect"]/span'''

    element_sel_gu = driver.find_element_by_xpath(xpath).click()

    

    time.sleep(1)

    

    xpath = '''//*[@id="glopopd_excel"]/span'''

    element_get_excel = driver.find_element_by_xpath(xpath).click()

    

    time.sleep(1)
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
